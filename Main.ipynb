# %% [markdown]
# # 91250 - Deep Learning

# %% [markdown]
# ## 0. Import and Configs

# %%
# File Operations
import gdown
import os
from pathlib import Path

# Math & Visualization
import random
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau

# Helpers
from sklearn.model_selection import train_test_split
import copy
import pprint as pp

# %%
# Set Device to GPU if available
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"CUDA Available: {torch.cuda.is_available()}")
# Out:
# CUDA Available: True

# %%
# Fixing seed to reduce randomness, for better comparisons
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

# %%
# Replace these IDs with the Google Drive file IDs supplied with the project.
TRAIN_FILE_ID = "1xyggntfZ2-6BTAagxJm-tFKDXerTAs8c"
TEST_FILE_ID  = "1VozRpr3dlVpA17BL-7ALCaOXa2vCe64J"

DATA_FOLDER = "data"
TRAIN_PATH = os.path.join(DATA_FOLDER,"chess_error_detection_train.csv")
TEST_PATH  = os.path.join(DATA_FOLDER,"chess_error_detection_test.csv")

MODEL_FOLDER = "model"
os.makedirs(MODEL_FOLDER, exist_ok=True)
BEST_MODEL_PATH = os.path.join(MODEL_FOLDER,"best_model.pt")

if not os.path.exists(TRAIN_PATH):
    gdown.download(id=TRAIN_FILE_ID, output=TRAIN_PATH, quiet=False)

if not os.path.exists(TEST_PATH):
    gdown.download(id=TEST_FILE_ID, output=TEST_PATH, quiet=False)

# %% [markdown]
# ## Data

# %%
train_df = pd.read_csv(TRAIN_PATH)
train_df, val_df = train_test_split(
    train_df,
    test_size=0.2,
    random_state=42,
    stratify=train_df["error_position"]
)
test_df = pd.read_csv(TEST_PATH)

print("Train shape:", train_df.shape)
print("Test shape: ", test_df.shape)

display(train_df.head())
# Out:
# Train shape: (320000, 3)
# Test shape:  (50000, 3)
#                                                  sequence  error_position  \
# 91975   g3 d5 e4 c4 Nf3 Bg4 Bg2 e5 O-O Bd6 d3 Nf6 c4 d...               4
# 252136  d4 e6 c4 d5 cxd5 Qxd5 e3 c5 Nc3 Qh5 Be2 Qg6 dx...               2
# 264691  e4 e6 Qf3 c5 exd5 exd5 Nc3 Nf6 h3 Bb4 g4 O-O g...               4
# 130957  e4 e5 Nf3 d6 Nf3 exd4 Nxd4 d5 exd5 Qxd5 Nc3 Qe...               5
# 240371  e4 g6 d4 Bg7 Nc3 dxe4 Nge2 c6 h3 Qc7 g4 e5 Bg2...               6
#
#        correct_move
# 91975            d4
# 252136          Nf6
# 264691           d5
# 130957           d4
# 240371           d6

# %% [markdown]
# ## Tokenization

# %%
unique_moves = set()
unique_moves.add("<PAD>")
unique_moves.add("<UNK>")

for game in train_df["sequence"]:
    for move in game.split():
        unique_moves.add(move)

print(len(unique_moves))
# Out:
# 3597

# %%
train_vocab = unique_moves

test_moves = []

for game in test_df["sequence"]:
    test_moves.extend(game.split())

unknown_unique = set(test_moves) - train_vocab
print("Unique unseen moves:", len(unknown_unique))

unknown_count = sum(move not in train_vocab for move in test_moves)
print("Unknown count:", unknown_count)
print("Unknown rate:", unknown_count / len(test_moves))
# Out:
# Unique unseen moves: 99
# Unknown count: 105
# Unknown rate: 5.25e-05

# %%
vocab_to_id = {
    "<PAD>": 0,
    "<UNK>": 1
}

for move in unique_moves:
    if move not in vocab_to_id:
        vocab_to_id[move] = len(vocab_to_id)

print("Vocabulary size:", len(vocab_to_id))
# Out:
# Vocabulary size: 3597

# %%
id_to_vocab = {
    idx: move
    for move, idx in vocab_to_id.items()
}

# %%
def encode_sequence(sequence, vocab_to_id):
    return [
        vocab_to_id.get(move, vocab_to_id["<UNK>"])
        for move in sequence.split()
    ]

# %%
sequence = train_df["sequence"].iloc[0]

encoded = encode_sequence(sequence, vocab_to_id)

print(sequence)
print(encoded)
print(len(encoded))
# Out:
# g3 d5 e4 c4 Nf3 Bg4 Bg2 e5 O-O Bd6 d3 Nf6 c4 dxc3 Nxc3 c6 Bg5 O-O Qd2 Nbd7 Bxf6 Qxf6 Nh4 g5 Nf5 Bb4 a3 Bxc3 Qxc3 Nb6 Ne3 Bf3 Bxf3 Qxf3 Ng2 Qf6 f4 gxf4 Nxf4 Na4
# [17, 1638, 185, 1372, 973, 2786, 1481, 8, 2804, 2733, 1672, 2735, 1372, 1751, 477, 2000, 1021, 2804, 2445, 1178, 1763, 2962, 2180, 3312, 3189, 2626, 1749, 502, 3099, 2088, 272, 1143, 2181, 270, 3306, 1715, 2087, 1317, 3451, 1665]
# 40

# %%
train_encoded = [
    encode_sequence(seq, vocab_to_id)
    for seq in train_df["sequence"]
]

val_encoded = [
    encode_sequence(seq, vocab_to_id)
    for seq in val_df["sequence"]
]

test_encoded = [
    encode_sequence(seq, vocab_to_id)
    for seq in test_df["sequence"]
]

# %%
train_labels = train_df["error_position"].to_numpy() - 1
val_labels = val_df["error_position"].to_numpy() - 1
test_labels = test_df["error_position"].to_numpy() - 1

# %%
x_train = torch.tensor(train_encoded, dtype=torch.long)
y_train = torch.tensor(train_labels, dtype=torch.long)

x_val = torch.tensor(val_encoded, dtype=torch.long)
y_val = torch.tensor(val_labels, dtype=torch.long)

x_test = torch.tensor(test_encoded, dtype=torch.long)
y_test = torch.tensor(test_labels, dtype=torch.long)

# %%
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=64,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=64,
    shuffle=False
)

# %% [markdown]
# ## Model Definition

# %%
class ChessErrorTransformer(nn.Module):
    def __init__(
        self,
        vocab_size,
        d_model=256,
        nhead=4,
        num_layers=3,
        dim_feedforward=256,
        dropout=0.1,
        max_len=40
    ):
        super().__init__()

        self.d_model = d_model
        self.max_len = max_len

        # SAN move → embedding vector
        self.token_embedding = nn.Embedding(
            vocab_size,
            d_model
        )

        # Position 0, 1, ..., 39 → embedding vector
        self.position_embedding = nn.Embedding(
            max_len,
            d_model
        )

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )

        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_layers
        )

        # Each candidate position gets one score
        self.classifier = nn.Linear(
            d_model,
            1
        )

    def forward(self, x):
        """
        x:
            [batch_size, 40]

        returns:
            [batch_size, 10]
        """

        batch_size, seq_len = x.shape

        # [40]
        positions = torch.arange(
            seq_len,
            device=x.device
        )

        # Token embeddings
        # [batch, 40, 128]
        token_embeddings = self.token_embedding(x)

        # Position embeddings
        # [40, 128]
        position_embeddings = self.position_embedding(positions)

        # Broadcasting gives:
        # [batch, 40, 128]
        x = token_embeddings + position_embeddings

        # Contextual representations
        # [batch, 40, 128]
        x = self.transformer(x)

        # We only need the first 10 positions
        # [batch, 10, 128]
        x = x[:, :10, :]

        # Score each candidate position
        # [batch, 10, 1]
        logits = self.classifier(x)

        # [batch, 10]
        logits = logits.squeeze(-1)

        return logits

# %%
vocab_size = len(vocab_to_id)

model = ChessErrorTransformer(
    vocab_size=vocab_size
)

total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params:,}")
# Out:
# Total parameters: 2,118,657

# %% [markdown]
# ## Train

# %%
model = model.to(DEVICE)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="max",       
    factor=0.1,      
    patience=3,      
    min_lr=1e-6
)

# %%
PATIENCE = 5
MAX_EPOCH = 100
best_model_path = "best_model.pt"

# Train flags
best_val_accuracy = 0.0
epochs_without_improvement = 0

# %%
def train(model, loader, optimizer, criterion, DEVICE):

    model.train()

    total_loss = 0
    total_correct = 0
    total_samples = 0

    for x, y in loader:

        x = x.to(DEVICE)
        y = y.to(DEVICE)

        # Clear old gradients
        optimizer.zero_grad()

        # Forward pass
        logits = model(x)

        # Classification loss
        loss = criterion(logits, y)

        # Backpropagation
        loss.backward()

        # Update parameters
        optimizer.step()

        # Statistics
        total_loss += loss.item() * x.size(0)

        predictions = logits.argmax(dim=1)

        total_correct += (
            predictions == y
        ).sum().item()

        total_samples += x.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples

    return avg_loss, accuracy

# %%
def evaluate(model, loader, criterion, device):

    model.eval()

    total_loss = 0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():

        for x, y in loader:

            x = x.to(device)
            y = y.to(device)

            logits = model(x)

            loss = criterion(logits, y)

            total_loss += loss.item() * x.size(0)

            predictions = logits.argmax(dim=1)

            total_correct += (
                predictions == y
            ).sum().item()

            total_samples += x.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples

    return avg_loss, accuracy

# %%
for epoch in range(MAX_EPOCH):
    train_loss, train_accuracy = train(
        model,
        train_loader,
        optimizer,
        criterion,
        DEVICE
    )

    val_loss, val_accuracy = evaluate(
        model,
        val_loader,
        criterion,
        DEVICE
    )

    scheduler.step(val_accuracy)

    #print(f"Epoch {epoch + 1:02d} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        epochs_without_improvement = 0

        torch.save(
            model.state_dict(),
            best_model_path
        )

        print(
            f"New best accuracy at Epoch {epoch+1}, Val Accuracy = {val_accuracy:.4f}"
        )
    else:
        epochs_without_improvement += 1

    current_lr = optimizer.param_groups[0]["lr"]

    print(
        f"Epoch [{epoch+1}/{MAX_EPOCH}] | "
        f"Train Loss: {train_loss:.4f} | "
        f"Train Acc: {train_accuracy:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Val Acc: {val_accuracy:.4f} | "
        f"LR: {current_lr:.2e}"
    )

    # Early Stopping
    if epochs_without_improvement >= PATIENCE:
        print(
            f"Early stopping triggered at epoch {epoch+1}. "
            f"Best Val Accuracy: {best_val_accuracy:.4f}"
        )
        break


# Load best model
model.load_state_dict(
    torch.load(best_model_path, map_location=DEVICE)
)

print(f"Best validation accuracy: {best_val_accuracy:.4f}")
# Out:
# New best accuracy at Epoch 1, Val Accuracy = 0.7770
# Epoch [1/100] | Train Loss: 1.0741 | Train Acc: 0.6100 | Val Loss: 0.6056 | Val Acc: 0.7770 | LR: 1.00e-04
# New best accuracy at Epoch 2, Val Accuracy = 0.8336
# Epoch [2/100] | Train Loss: 0.5773 | Train Acc: 0.7857 | Val Loss: 0.4471 | Val Acc: 0.8336 | LR: 1.00e-04
# New best accuracy at Epoch 3, Val Accuracy = 0.8591
# Epoch [3/100] | Train Loss: 0.4459 | Train Acc: 0.8328 | Val Loss: 0.3751 | Val Acc: 0.8591 | LR: 1.00e-04
# New best accuracy at Epoch 4, Val Accuracy = 0.8727
# Epoch [4/100] | Train Loss: 0.3731 | Train Acc: 0.8591 | Val Loss: 0.3350 | Val Acc: 0.8727 | LR: 1.00e-04
# New best accuracy at Epoch 5, Val Accuracy = 0.8830
# Epoch [5/100] | Train Loss: 0.3226 | Train Acc: 0.8771 | Val Loss: 0.3079 | Val Acc: 0.8830 | LR: 1.00e-04
# New best accuracy at Epoch 6, Val Accuracy = 0.8918
# Epoch [6/100] | Train Loss: 0.2873 | Train Acc: 0.8897 | Val Loss: 0.2879 | Val Acc: 0.8918 | LR: 1.00e-04
# New best accuracy at Epoch 7, Val Accuracy = 0.8962
# Epoch [7/100] | Train Loss: 0.2613 | Train Acc: 0.8992 | Val Loss: 0.2739 | Val Acc: 0.8962 | LR: 1.00e-04
# New best accuracy at Epoch 8, Val Accuracy = 0.8998
# Epoch [8/100] | Train Loss: 0.2378 | Train Acc: 0.9076 | Val Loss: 0.2694 | Val Acc: 0.8998 | LR: 1.00e-04
# New best accuracy at Epoch 9, Val Accuracy = 0.9007
# Epoch [9/100] | Train Loss: 0.2197 | Train Acc: 0.9138 | Val Loss: 0.2667 | Val Acc: 0.9007 | LR: 1.00e-04
# New best accuracy at Epoch 10, Val Accuracy = 0.9046
# Epoch [10/100] | Train Loss: 0.2048 | Train Acc: 0.9198 | Val Loss: 0.2540 | Val Acc: 0.9046 | LR: 1.00e-04
# Epoch [11/100] | Train Loss: 0.1928 | Train Acc: 0.9238 | Val Loss: 0.2626 | Val Acc: 0.9042 | LR: 1.00e-04
# New best accuracy at Epoch 12, Val Accuracy = 0.9072
# Epoch [12/100] | Train Loss: 0.1807 | Train Acc: 0.9284 | Val Loss: 0.2520 | Val Acc: 0.9072 | LR: 1.00e-04
# New best accuracy at Epoch 13, Val Accuracy = 0.9097
# Epoch [13/100] | Train Loss: 0.1693 | Train Acc: 0.9326 | Val Loss: 0.2542 | Val Acc: 0.9097 | LR: 1.00e-04
# Epoch [14/100] | Train Loss: 0.1621 | Train Acc: 0.9349 | Val Loss: 0.2576 | Val Acc: 0.9088 | LR: 1.00e-04
# New best accuracy at Epoch 15, Val Accuracy = 0.9101
# Epoch [15/100] | Train Loss: 0.1557 | Train Acc: 0.9377 | Val Loss: 0.2559 | Val Acc: 0.9101 | LR: 1.00e-04
# New best accuracy at Epoch 16, Val Accuracy = 0.9103
# Epoch [16/100] | Train Loss: 0.1485 | Train Acc: 0.9410 | Val Loss: 0.2603 | Val Acc: 0.9103 | LR: 1.00e-04
# New best accuracy at Epoch 17, Val Accuracy = 0.9114
# Epoch [17/100] | Train Loss: 0.1420 | Train Acc: 0.9435 | Val Loss: 0.2565 | Val Acc: 0.9114 | LR: 1.00e-04
# New best accuracy at Epoch 18, Val Accuracy = 0.9118
# Epoch [18/100] | Train Loss: 0.1362 | Train Acc: 0.9453 | Val Loss: 0.2577 | Val Acc: 0.9118 | LR: 1.00e-04
# Epoch [19/100] | Train Loss: 0.1317 | Train Acc: 0.9474 | Val Loss: 0.2629 | Val Acc: 0.9109 | LR: 1.00e-04
# New best accuracy at Epoch 20, Val Accuracy = 0.9122
# Epoch [20/100] | Train Loss: 0.1279 | Train Acc: 0.9485 | Val Loss: 0.2543 | Val Acc: 0.9122 | LR: 1.00e-04
# New best accuracy at Epoch 21, Val Accuracy = 0.9128
# Epoch [21/100] | Train Loss: 0.1228 | Train Acc: 0.9508 | Val Loss: 0.2618 | Val Acc: 0.9128 | LR: 1.00e-04
# New best accuracy at Epoch 22, Val Accuracy = 0.9128
# Epoch [22/100] | Train Loss: 0.1190 | Train Acc: 0.9523 | Val Loss: 0.2613 | Val Acc: 0.9128 | LR: 1.00e-04
# Epoch [23/100] | Train Loss: 0.1159 | Train Acc: 0.9531 | Val Loss: 0.2671 | Val Acc: 0.9116 | LR: 1.00e-04
# New best accuracy at Epoch 24, Val Accuracy = 0.9142
# Epoch [24/100] | Train Loss: 0.1139 | Train Acc: 0.9545 | Val Loss: 0.2638 | Val Acc: 0.9142 | LR: 1.00e-04
# New best accuracy at Epoch 25, Val Accuracy = 0.9150
# Epoch [25/100] | Train Loss: 0.1090 | Train Acc: 0.9561 | Val Loss: 0.2566 | Val Acc: 0.9150 | LR: 1.00e-04
# New best accuracy at Epoch 26, Val Accuracy = 0.9151
# Epoch [26/100] | Train Loss: 0.1064 | Train Acc: 0.9574 | Val Loss: 0.2663 | Val Acc: 0.9151 | LR: 1.00e-04
# New best accuracy at Epoch 27, Val Accuracy = 0.9152
# Epoch [27/100] | Train Loss: 0.1037 | Train Acc: 0.9584 | Val Loss: 0.2654 | Val Acc: 0.9152 | LR: 1.00e-04
# Epoch [28/100] | Train Loss: 0.1017 | Train Acc: 0.9598 | Val Loss: 0.2634 | Val Acc: 0.9147 | LR: 1.00e-04
# New best accuracy at Epoch 29, Val Accuracy = 0.9163
# Epoch [29/100] | Train Loss: 0.0984 | Train Acc: 0.9607 | Val Loss: 0.2671 | Val Acc: 0.9163 | LR: 1.00e-04
# Epoch [30/100] | Train Loss: 0.0969 | Train Acc: 0.9616 | Val Loss: 0.2623 | Val Acc: 0.9160 | LR: 1.00e-04
# New best accuracy at Epoch 31, Val Accuracy = 0.9170
# Epoch [31/100] | Train Loss: 0.0946 | Train Acc: 0.9631 | Val Loss: 0.2716 | Val Acc: 0.9170 | LR: 1.00e-04
# Epoch [32/100] | Train Loss: 0.0927 | Train Acc: 0.9637 | Val Loss: 0.2717 | Val Acc: 0.9162 | LR: 1.00e-04
# Epoch [33/100] | Train Loss: 0.0902 | Train Acc: 0.9643 | Val Loss: 0.2723 | Val Acc: 0.9157 | LR: 1.00e-04
# Epoch [34/100] | Train Loss: 0.0881 | Train Acc: 0.9653 | Val Loss: 0.2743 | Val Acc: 0.9167 | LR: 1.00e-04
# Epoch [35/100] | Train Loss: 0.0856 | Train Acc: 0.9663 | Val Loss: 0.2806 | Val Acc: 0.9154 | LR: 1.00e-05
# New best accuracy at Epoch 36, Val Accuracy = 0.9211
# Epoch [36/100] | Train Loss: 0.0615 | Train Acc: 0.9762 | Val Loss: 0.2756 | Val Acc: 0.9211 | LR: 1.00e-05
# New best accuracy at Epoch 37, Val Accuracy = 0.9222
# Epoch [37/100] | Train Loss: 0.0521 | Train Acc: 0.9794 | Val Loss: 0.2838 | Val Acc: 0.9222 | LR: 1.00e-05
# New best accuracy at Epoch 38, Val Accuracy = 0.9227
# Epoch [38/100] | Train Loss: 0.0483 | Train Acc: 0.9813 | Val Loss: 0.2879 | Val Acc: 0.9227 | LR: 1.00e-05
# New best accuracy at Epoch 39, Val Accuracy = 0.9233
# Epoch [39/100] | Train Loss: 0.0456 | Train Acc: 0.9823 | Val Loss: 0.2878 | Val Acc: 0.9233 | LR: 1.00e-05
# Epoch [40/100] | Train Loss: 0.0431 | Train Acc: 0.9833 | Val Loss: 0.2937 | Val Acc: 0.9228 | LR: 1.00e-05
# New best accuracy at Epoch 41, Val Accuracy = 0.9234
# Epoch [41/100] | Train Loss: 0.0419 | Train Acc: 0.9837 | Val Loss: 0.2965 | Val Acc: 0.9234 | LR: 1.00e-05
# Epoch [42/100] | Train Loss: 0.0408 | Train Acc: 0.9840 | Val Loss: 0.2986 | Val Acc: 0.9231 | LR: 1.00e-05
# Epoch [43/100] | Train Loss: 0.0387 | Train Acc: 0.9851 | Val Loss: 0.3052 | Val Acc: 0.9234 | LR: 1.00e-06
# Epoch [44/100] | Train Loss: 0.0365 | Train Acc: 0.9859 | Val Loss: 0.3043 | Val Acc: 0.9233 | LR: 1.00e-06
# New best accuracy at Epoch 45, Val Accuracy = 0.9235
# Epoch [45/100] | Train Loss: 0.0363 | Train Acc: 0.9860 | Val Loss: 0.3044 | Val Acc: 0.9235 | LR: 1.00e-06
# New best accuracy at Epoch 46, Val Accuracy = 0.9236
# Epoch [46/100] | Train Loss: 0.0359 | Train Acc: 0.9861 | Val Loss: 0.3048 | Val Acc: 0.9236 | LR: 1.00e-06
# Epoch [47/100] | Train Loss: 0.0358 | Train Acc: 0.9862 | Val Loss: 0.3055 | Val Acc: 0.9235 | LR: 1.00e-06
# New best accuracy at Epoch 48, Val Accuracy = 0.9237
# Epoch [48/100] | Train Loss: 0.0355 | Train Acc: 0.9864 | Val Loss: 0.3064 | Val Acc: 0.9237 | LR: 1.00e-06
# New best accuracy at Epoch 49, Val Accuracy = 0.9239
# Epoch [49/100] | Train Loss: 0.0356 | Train Acc: 0.9863 | Val Loss: 0.3066 | Val Acc: 0.9239 | LR: 1.00e-06
# Epoch [50/100] | Train Loss: 0.0355 | Train Acc: 0.9864 | Val Loss: 0.3070 | Val Acc: 0.9237 | LR: 1.00e-06
# Epoch [51/100] | Train Loss: 0.0343 | Train Acc: 0.9867 | Val Loss: 0.3076 | Val Acc: 0.9237 | LR: 1.00e-06
# Epoch [52/100] | Train Loss: 0.0349 | Train Acc: 0.9868 | Val Loss: 0.3076 | Val Acc: 0.9238 | LR: 1.00e-06
# Epoch [53/100] | Train Loss: 0.0344 | Train Acc: 0.9868 | Val Loss: 0.3076 | Val Acc: 0.9235 | LR: 1.00e-06
# Epoch [54/100] | Train Loss: 0.0349 | Train Acc: 0.9869 | Val Loss: 0.3076 | Val Acc: 0.9236 | LR: 1.00e-06
# Early stopping triggered at epoch 54. Best Val Accuracy: 0.9239
# Best validation accuracy: 0.9239

# %% [markdown]
# ## Final Evaluation

# %%
# Evaluation mode
model.eval()

# No gradients needed
with torch.no_grad():

    test_loss, test_acc = evaluate(
        model,
        test_loader,
        criterion,
        DEVICE
    )

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy@1: {test_acc * 100:.2f}%")
# Out:
# Test Loss: 0.3095
# Test Accuracy@1: 92.25%
